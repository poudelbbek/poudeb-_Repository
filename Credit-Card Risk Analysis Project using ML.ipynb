# %% [markdown]
# # Loading Data into Jupyter

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\poude\Desktop\NewCreditCard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.758743e-12 -8.252298e-13 -9.636929e-13  8.316157e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.591952e-13  4.247354e-13 -3.050180e-13  8.693344e-14 -1.179712e-12
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(data['Class'])

# %%
fraud = data[data['Class']==1]
normal = data[data['Class']==0]

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fig, (ax1, ax2) =  plt.subplots(2,1)

ax1.hist(fraud.Amount, bins = 50)
ax2.hist(normal.Amount, bins = 30)
plt.xlim(0,2000)
ax1.set_title(" Fraud Amount")

plt.ylabel("No of Transaction")
plt.tight_layout()

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  3.777386e-12 -2.119585e-12 -1.724017e-13
# V2     -0.010593  3.777386e-12  1.000000e+00  2.326821e-12 -2.314711e-12
# V3     -0.419618 -2.119585e-12  2.326821e-12  1.000000e+00  2.036710e-13
# V4     -0.105260 -1.724017e-13 -2.314711e-12  2.036710e-13  1.000000e+00
# V5      0.173072 -3.472870e-12 -1.832637e-12 -4.031527e-12 -2.549916e-13
# V6     -0.063016 -1.306592e-13  9.439633e-13 -1.582965e-13  1.083580e-12
# V7      0.084714 -1.127393e-13  5.403061e-12  3.404521e-12  8.130086e-13
# V8     -0.036949  2.115132e-12  2.153414e-14 -1.271766e-12  7.338233e-13
# V9     -0.008660  3.081639e-14  3.239499e-13 -6.819934e-13 -7.138427e-13
# V10     0.030617 -2.615209e-12  1.463139e-12 -1.611234e-12 -1.938801e-12
# V11    -0.247689  1.866050e-12 -8.312889e-13  8.717778e-13  1.875265e-12
# ...

# %%
sns.heatmap(data.corr())

# %%
data.corr()["Class"]
# Out:
# Time     -0.012323
# V1       -0.101347
# V2        0.091289
# V3       -0.192961
# V4        0.133447
# V5       -0.094974
# V6       -0.043643
# V7       -0.187257
# V8        0.019875
# V9       -0.097733
# V10      -0.216883
# V11       0.154876
# V12      -0.260593
# V13      -0.004570
# V14      -0.302544
# V15      -0.004223
# V16      -0.196539
# V17      -0.326481
# V18      -0.111485
# V19       0.034783
# V20       0.020090
# V21       0.040413
# V22       0.000805
# V23      -0.002685
# V24      -0.007221
# V25       0.003308
# V26       0.004455
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# Class     1.000000
# Name: Class, dtype: float64

# %%
fig, (axes1,axes2) = plt.subplots(1,2, figsize=(15,5))
sns.distplot(data["Amount"],kde=False,ax=axes1 )
sns.distplot(data["Time"],kde=False )
axes1.set_title("Distribution of Amount")
axes2.set_title("Distribution of Time")
# Out:
# Text(0.5, 1.0, 'Distribution of Time')

# %%
from sklearn.preprocessing import StandardScaler
Ss=StandardScaler()

# %%
data['scaled_time']=Ss.fit_transform(data["Time"].values.reshape(-1,1))

data['scaled_amount']=Ss.fit_transform(data["Amount"].values.reshape(-1,1))

# %%
fig, (axes1,axes2) = plt.subplots(1,2, figsize=(15,5))
sns.distplot(data["scaled_amount"],kde=False,ax=axes1 )
sns.distplot(data["scaled_time"],kde=False )
axes1.set_title("Distribution of Scaled Amount")
axes2.set_title("Distribution of Scaled Time")
# Out:
# Text(0.5, 1.0, 'Distribution of Scaled Time')

# %%
pd.concat([data,data['scaled_time'],data['scaled_amount']],axis=1)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V25       V26  \
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class', 'scaled_time', 'scaled_amount'],
#       dtype='object')

# %%
data.drop(axis=1, columns=['Amount','Time'], inplace = True)

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class', 'scaled_time',
#        'scaled_amount'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X=data[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
       'scaled_amount', 'scaled_time']]
y=data["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lr=LogisticRegression()

# %%
Lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=Lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85299
#            1       0.88      0.61      0.72       144
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[85287    12]
#  [   56    88]]

# %%
from imblearn import over_sampling
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(random_state=2)

# %%
X_SMtrain, y_SMtrain=sm.fit_sample(X_train,y_train.ravel())

# %%
sns.countplot(x=y_SMtrain, data= data)

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(X_SMtrain,y_SMtrain)
# Out:
# LogisticRegression()

# %%
pred= lg.predict(X_test)

# %%
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[83289  2010]
#  [   13   131]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85299
#            1       0.06      0.91      0.11       144
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.94      0.55     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_SMtrain,y_SMtrain)
# Out:
# DecisionTreeClassifier()

# %%
pred_d=dtc.predict(X_test)

# %%
print(confusion_matrix(y_test, pred_d))
print(classification_report(y_test, pred_d))
# Out:
# [[85104   195]
#  [   33   111]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85299
#            1       0.36      0.77      0.49       144
#
#     accuracy                           1.00     85443
#    macro avg       0.68      0.88      0.75     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators= 600)

# %%
rfc.fit(X_SMtrain,y_SMtrain)
# Out:
# RandomForestClassifier(n_estimators=600)

# %%
pred=rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[85286    13]
#  [   24   120]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85299
#            1       0.90      0.83      0.87       144
#
#     accuracy                           1.00     85443
#    macro avg       0.95      0.92      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Out:
# C:\Users\poude\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\poude\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\poude\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
X_SMtrain.shape
# Out:
# (398032, 30)

# %%
model=Sequential()
model.add(Dense(input_dim=30,units=30, activation = "relu"))
model.add(Dropout(0.4))
model.add(Dense(15, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))
model.compile(loss="binary_crossentropy",optimizer="adam")

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5)

# %%
model.fit(x=X_SMtrain, y =y_SMtrain, epochs=100, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Train on 398032 samples, validate on 85443 samples
# Epoch 1/100
# 398032/398032 [==============================] - 14s 35us/sample - loss: 0.0552 - val_loss: 0.0177
# Epoch 2/100
# 398032/398032 [==============================] - 14s 35us/sample - loss: 0.0202 - val_loss: 0.0173
# Epoch 3/100
# 398032/398032 [==============================] - 15s 38us/sample - loss: 0.0180 - val_loss: 0.0180
# Epoch 4/100
# 398032/398032 [==============================] - 13s 32us/sample - loss: 0.0161 - val_loss: 0.0191
# Epoch 5/100
# 398032/398032 [==============================] - 13s 33us/sample - loss: 0.0150 - val_loss: 0.0204
# Epoch 6/100
# 398032/398032 [==============================] - 18s 46us/sample - loss: 0.0141 - val_loss: 0.0209
# Epoch 7/100
# 398032/398032 [==============================] - 18s 46us/sample - loss: 0.0133 - val_loss: 0.0208
# Epoch 00007: early stopping

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss.plot()

# %%
predictions=model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85299
#            1       0.42      0.87      0.56       144
#
#     accuracy                           1.00     85443
#    macro avg       0.71      0.93      0.78     85443
# weighted avg       1.00      1.00      1.00     85443
#
# [[85124   175]
#  [   19   125]]
